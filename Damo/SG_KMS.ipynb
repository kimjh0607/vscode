# %% [markdown]
# ### 암호화에서 가장 중요한 것은 암호화시 사용하는 `Key`

# %% [markdown]
# 키요청시 agent인증과 개별 권한을 확인함. IP, AGENT ID, 기간 등
#
# HA구성. 물리적으로 떨어진 DR센터에 운영장비의 주기적인 정책동기화 등을 구성하기도 함.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
