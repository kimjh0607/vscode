# %% [markdown]
# ## GUI 관리도구
# - 61.109.216.208:5001
# - admin1
# - penta7728.

# %% [markdown]
# ## CLI 접근
# - 61.109.216.116 ID: rocky // pem파일첨부후 ssh접속
# - ssh -i hrdk-qa.pem pentasec@10.0.16.95 -p 5022
# - enable / Penta@1997

# %% [markdown]
# ![image.png](attachment:image.png)
